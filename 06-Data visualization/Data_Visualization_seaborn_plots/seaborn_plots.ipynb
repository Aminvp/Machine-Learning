# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# نمودارهای سیبورن
# </font>
# </h1>

# %% [markdown]
# <h2 dir = rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# کار با regplot
# </font>
# </h2>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در کد زیر با استفاده از متد <code>regplot</code> رابطه قیمت و قیراط بعضی الماسهای مصطفی را روی نمودار نشان می‌دهیم:
# </font>
# </p>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

fig , ax = plt.subplots()

price = [921, 3087, 7196, 4201, 982, 3534, 9930, 8518, 12825, 7404, 4032, 878, 1240, 945, 10446, 5530, 720, 2846, 3064]
carat = [0.42, 0.76, 1.21, 0.91, 0.4, 1.02, 1.24, 1.5, 1.31, 1.13, 0.57, 0.41, 0.49, 0.42, 1.14, 0.91, 0.32, 0.77, 0.8]

sns.regplot(x = price, y = carat , ax= ax)
ax.set_title("carat vs price for diamonds")
ax.set_xlabel("carat")
ax.set_ylabel("price");

# %% [markdown]
# <h2 dir = rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# کار با displot
# </font>
# </h2>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در کد زیر، چگالی و هیستوگرام قد بازیکنان فیفا ۲۱ را رسم می‌کنیم:
# </font>
# </p>

# %%
import pandas as pd

df = pd.read_csv('fifa21.csv')
sns.displot(df, x='height', bins = 30, color = 'red',kde=True);

# %% [markdown]
# <h2 dir = rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# کار با jointplot
# </font>
# </h2>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در کد زیر، بار دیگر رابطه قد و وزن بازیکنان فوتبال را به روشی متفاوت‌تر بررسی می‌کنیم:
# </font>
# </p>

# %%
plot = sns.jointplot(data = df, x='height' ,y='weight', kind = 'kde', color='purple')
