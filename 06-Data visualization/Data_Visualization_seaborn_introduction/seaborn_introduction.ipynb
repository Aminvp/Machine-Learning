# %% [markdown]
# <h1>
# <div dir=rtl>
# 		<div align=center>
# <font face="vazir" color="#0099cc">
# آشنایی با سیبورن
# </font>
# </div>
# </h1>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در کد زیر یک نمودار شامل دو صفحه محور رسم می‌کنیم که شامل اطلاعات یک سایت فروش می‌باشد:
# </font>
# </p>

# %%
import matplotlib.pyplot as plt

fig , axes = plt.subplots(1,2, figsize = (9,3.5))
fig.suptitle('website analysis')

axes[0].set_title('views')
axes[0].set_xlabel('day')
axes[0].set_ylabel('count')
axes[0].plot([10,15,12,18,9,13,12],label = 'this week')
axes[0].plot([8,9,13,10,11,14,15],label = 'last week')
axes[0].legend()

axes[1].set_title('new accounts')
axes[1].set_xlabel('day')
axes[1].set_ylabel('count')
axes[1].bar([0,1,2,3,4,5,6],[6,4,4,3,2,4,5])
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# <br />
# <div dir=rtl id="start" style="direction:rtl;line-height:200%;">
# 	<font face="vazir" size=3>
#   <p>
#   <p></p>
#
# می‌توان از سیبورن به عنوان تِمی برای مت‌پلات استفاده کرد. برای اینکار کافیست که سیبورن را import‌ کنیم و متد set_theme را صدا بزنیم. پس از آن هر نموداری که با مت‌پلات کشیده می‌شود، ظاهر سیبورن را به خود می‌گیرد. در کد زیر نمودار بالا را با تم سیبورن می‌کشیم.
#
#   </p>
# </div>

# %%
import seaborn as sns
sns.set_theme()

fig , axes = plt.subplots(1,2, figsize = (9,3.5))
fig.suptitle('website analysis')

axes[0].set_title('views')
axes[0].set_xlabel('day')
axes[0].set_ylabel('count')
axes[0].plot([10,15,12,18,9,13,12],label = 'this week')
axes[0].plot([8,9,13,10,11,14,15],label = 'last week')
axes[0].legend()

axes[1].set_title('new accounts')
axes[1].set_xlabel('day')
axes[1].set_ylabel('count')
axes[1].bar([0,1,2,3,4,5,6],[6,4,4,3,2,4,5])
# Out:
# <BarContainer object of 7 artists>
